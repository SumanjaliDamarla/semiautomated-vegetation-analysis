# %%
import geopandas

# %%
import os

# %%
import pandas as pd
import numpy as np

# %%
cwd = os.getcwd()

# %%
India_shapefile = cwd + "\\Command_area\\assembly-constituencies\\India_AC.shp"
print(os.path.exists(India_shapefile))
# Out:
# True

# %%
India = geopandas.read_file(India_shapefile)

# %%
godavari_acs = [
    "Ungutur", 
    "Tadepalligudem", 
    "Undi", 
    "Bhimavaram", 
    "Narasapuram", 
    "Razole (SC)", 
    "Palacole", 
    "Achanta", 
    "Tanuku", 
    "Nidadavole", 
    "Gannavaram (SC)", 
    "Kothapeta", 
    "Amalapuram (SC)", 
    "Mummidivaram", 
    "Ramachandrapuram", 
    "Rajahmundry Rural", 
    "Mandapeta", 
    "Anaparthy", 
    "Pithapuram", 
    "Peddapuram", 
    "Kakinada Rural"
]
godavari =  India["AC_NAME"].isin(godavari_acs)
godavari = India[godavari]

# %%
krishna_acs = [
    "Prathipadu (SC)",
    "Ponnur",
    "Bapatla",
    "Vemuru (SC)",
    "Repalle",
    "Tenali",
    "Mangalagiri",
    "Penamaluru",
    "Pamarru (SC)",
    "Avanigadda",
    "Machilipatnam",
    "Pedana",
    "Gudivada",
    "Gannavaram",
    "Denduluru",
    "Eluru",
    "Kaikalur"
]
krishna =  India["AC_NAME"].isin(krishna_acs)
krishna = India[krishna]

# %%
krishna.plot()

# %%
godavari.plot()

# %%
godavari.to_file("GodavariMapShape")

# %%
krishna.to_file("KrishnaMapShape")
